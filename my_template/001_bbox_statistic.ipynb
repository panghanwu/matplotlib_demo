# %%
import matplotlib.pyplot as plt

# %%
"""
Bar
"""

n = len(statistic)
x = [i for i in range(10)]
y = list(statistic.values())

# set axes
plt.xlim(-1, n)
plt.ylim(0, max(y)*1.1)
plt.xticks((x))

# plot
plt.bar(x, y, facecolor='#9999ff', edgecolor='white')

# add annotation
for i, j in zip(x, y):
    plt.text(i, j, '{:d}'.format(j), ha='center', va='bottom')
    # ha: horizontal alignment, va: vertical alignment

plt.show()

# %%
"""
Scatter
"""

x = arctans
y = diagonals
color = list(map(float,labels))  # generate color value

fig, ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('Arctan', fontsize=20)
ax.set_ylabel('Diagonal', fontsize=20)
# plot
sca = ax.scatter(x, y, s=20, c=color, cmap='rainbow', label=color, alpha=.5)
# add legend
ax.legend(*sca.legend_elements(), bbox_to_anchor=(1.05, 1.0), loc='upper left', title='Classes')

plt.show()

# %%
"""
Histogram
"""

plt.figure(figsize=(12, 4))

plt.subplot(121)
plt.hist(arctans, 50, density=False, facecolor='green', alpha=0.75)
plt.title('Arctan', fontsize=30)

plt.subplot(122)
plt.hist(diagonals,50, density=False, facecolor='brown', alpha=0.75)
plt.title('Diagonal', fontsize=30)
plt.show()
